# %% [markdown]
# <a href="https://colab.research.google.com/github/deepak1195/NaturalLanguageProcessing/blob/main/008_StopWords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
from numpy.ma.core import shape
path="/content/drive/MyDrive/myWork/Data/"
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv(f'{path}spam.csv')
df
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
nlp=spacy.load('en_core_web_sm')
def removeStopWords(txt):
  doc=nlp(txt)
  clean=[tk.text for tk in doc if not tk.is_stop]
  return ' '.join(clean)

# %%
df['Message'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
df['Message']=df['Message'].apply(removeStopWords)
df['Message'][0]
# Out:
# 'jurong point , crazy .. Available bugis n great world la e buffet ... Cine got amore wat ...'

# %%
df['Category']=df['Category'].apply(lambda x:1 if x=='spam' else 0)
df
# Out:
#       Category                                            Message
# 0            0  jurong point , crazy .. Available bugis n grea...
# 1            0                    Ok lar ... Joking wif u oni ...
# 2            1  Free entry 2 wkly comp win FA Cup final tkts 2...
# 3            0                        U dun early hor ... U c ...
# 4            0                         Nah think goes usf , lives
# ...        ...                                                ...
# 5567         1  2nd time tried 2 contact u. U won £ 750 Pound ...
# 5568         0                      ü b going esplanade fr home ?
# 5569         0                  Pity , * mood . ... suggestions ?
# 5570         0  guy bitching acted like interested buying week...
# 5571         0                                        Rofl . true
#
# [5572 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
xTrain,xTest,yTrain,yTest=train_test_split(df['Message'],df['Category'],test_size=0.2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

model=Pipeline([
    ('CV',CountVectorizer()),
    ('NB',MultinomialNB())
])
model.fit(xTrain, yTrain)
# Out:
# Pipeline(steps=[('CV', CountVectorizer()), ('NB', MultinomialNB())])

# %%
yPred=model.predict(xTest)
yPred
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report
print(classification_report(yTest,yPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       957
#            1       0.98      0.94      0.96       158
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.97      0.98      1115
# weighted avg       0.99      0.99      0.99      1115
