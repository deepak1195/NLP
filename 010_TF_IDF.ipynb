# %% [markdown]
# <a href="https://colab.research.google.com/github/deepak1195/NaturalLanguageProcessing/blob/main/010_TF_IDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
from numpy.ma.core import shape
path="/content/drive/MyDrive/myWork/Data/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv(f'{path}Ecommerce_data.csv')
df
# Out:
#                                                     Text  \
# 0      Urban Ladder Eisner Low Back Study-Office Comp...
# 1      Contrast living Wooden Decorative Box,Painted ...
# 2      IO Crest SY-PCI40010 PCI RAID Host Controller ...
# 3      ISAKAA Baby Socks from Just Born to 8 Years- P...
# 4      Indira Designer Women's Art Mysore Silk Saree ...
# ...                                                  ...
# 23995                 Marvel Physics MCQ's for MHT - CET
# 23996  Internet Download Manager | Lifetime License |...
# 23997  Sadhubela's Handcrafted Iron Degchi Handi Pot ...
# 23998  Audio-Technica AT-LP60 Automatic Belt Driven D...
# 23999  LG GH24NSB0 DVD Writer 24X SATA Internal OEM P...
#
#                         label
# 0                   Household
# 1                   Household
# 2                 Electronics
# 3      Clothing & Accessories
# 4      Clothing & Accessories
# ...                       ...
# 23995                   Books
# 23996                   Books
# 23997               Household
# 23998             Electronics
# 23999             Electronics
#
# [24000 rows x 2 columns]

# %%
df.label.value_counts()
# Out:
# Household                 6000
# Electronics               6000
# Clothing & Accessories    6000
# Books                     6000
# Name: label, dtype: int64

# %%
import re
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
nlp=spacy.load('en_core_web_sm')
def preprocessText(txt):
  doc=nlp(re.sub(r'[^\w\s]', '',txt))
  clean=[tk.lemma_ for tk in doc if not tk.is_stop]
  return ' '.join(clean).replace(' ,','')

df['Text']=df.Text.apply(preprocessText)
df
# Out:
#                                                     Text  \
# 0      Urban Ladder Eisner Low StudyOffice Computer C...
# 1      contrast live Wooden Decorative BoxPainted Box...
# 2      IO Crest SYPCI40010 pci raid Host Controller C...
# 3      ISAKAA Baby Socks bear 8 year Pack 4 6 8 12 IS...
# 4      Indira Designer Womens Art Mysore Silk Saree B...
# ...                                                  ...
# 23995                       Marvel Physics mcq MHT   CET
# 23996  internet Download Manager   Lifetime License  ...
# 23997  Sadhubelas Handcrafted Iron Degchi Handi Pot  ...
# 23998  AudioTechnica atlp60 Automatic Belt Driven dj ...
# 23999  LG GH24NSB0 DVD Writer 24x SATA Internal OEM p...
#
#                         label
# 0                   Household
# 1                   Household
# 2                 Electronics
# 3      Clothing & Accessories
# 4      Clothing & Accessories
# ...                       ...
# 23995                   Books
# 23996                   Books
# 23997               Household
# 23998             Electronics
# 23999             Electronics
#
# [24000 rows x 2 columns]

# %%
df['label']=df.label.map({'Household':0,'Electronics':1,'Clothing & Accessories':2,'Books':3})
df
# Out:
#                                                     Text  label
# 0      Urban Ladder Eisner Low StudyOffice Computer C...      0
# 1      contrast live Wooden Decorative BoxPainted Box...      0
# 2      IO Crest SYPCI40010 pci raid Host Controller C...      1
# 3      ISAKAA Baby Socks bear 8 year Pack 4 6 8 12 IS...      2
# 4      Indira Designer Womens Art Mysore Silk Saree B...      2
# ...                                                  ...    ...
# 23995                       Marvel Physics mcq MHT   CET      3
# 23996  internet Download Manager   Lifetime License  ...      3
# 23997  Sadhubelas Handcrafted Iron Degchi Handi Pot  ...      0
# 23998  AudioTechnica atlp60 Automatic Belt Driven dj ...      1
# 23999  LG GH24NSB0 DVD Writer 24x SATA Internal OEM p...      1
#
# [24000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
xTrain,xTest,yTrain,yTest=train_test_split(df.Text, df.label, test_size=0.25, random_state=2023, stratify=df.label)

# %%
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import TfidfVectorizer

model=Pipeline([
    ('TF-IDF',TfidfVectorizer()),
    ('KNN',KNeighborsClassifier())
])

model.fit(xTrain,yTrain)
# Out:
# Pipeline(steps=[('TF-IDF', TfidfVectorizer()), ('KNN', KNeighborsClassifier())])

# %%
yPred=model.predict(xTest)
yPred
# Out:
# array([3, 0, 0, ..., 0, 1, 1])

# %%
from inspect import classify_class_attrs
from sklearn.metrics import classification_report
print(classification_report(yTest,yPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      1500
#            1       0.96      0.97      0.97      1500
#            2       0.97      0.98      0.98      1500
#            3       0.97      0.93      0.95      1500
#
#     accuracy                           0.96      6000
#    macro avg       0.96      0.96      0.96      6000
# weighted avg       0.96      0.96      0.96      6000

# %%
v=model['TF-IDF']
print(dict(list(v.vocabulary_.items())[0: 50]))
# Out:
# {'grit': 24943, 'passion': 39328, 'resilience': 43966, 'secret': 45973, 'success': 50079, 'review': 44147, 'persuasive': 39902, 'fascinating': 21792, 'response': 44023, 'cult': 16480, 'iq': 28938, 'fundamentalism': 23477, 'duckworth': 19240, 'remind': 43740, 'character': 13363, 'perseverance': 39864, 'set': 46386, 'successful': 50082, 'apart': 7998, 'malcolm': 33080, 'gladwellimpressively': 24289, 'fresh': 23228, 'original': 38401, 'scrub': 45791, 'away': 9126, 'preconception': 41360, 'far': 21766, 'potential': 41159, 'solve': 48408, 'riddle': 44335, 'likely': 31851, 'succeed': 50076, 'fact': 21606, 'buy': 12034, 'send': 46238, 'copy': 15739, 'friend': 23260, 'tell': 51375, 'world': 56870, 'hope': 26817, 'dazzle': 17023, 'susan': 50510, 'cain': 12251, 'new': 36845, 'york': 57529, 'times': 52069, 'bestselle': 10166, 'authorat': 8927, 'time': 52018, 'collective': 14502}

# %%
feature_names=v.get_feature_names_out()[10000:10050]
feature_names
# Out:
# array(['belarus', 'belazo', 'belegal', 'belem', 'belgian', 'belgium',
#        'belha', 'belief', 'beliefs', 'believable', 'believably',
#        'believe', 'believer', 'believers', 'belittling', 'belkin', 'bell',
#        'bella', 'bellaigue', 'belle', 'bellevue', 'bellingham', 'bellows',
#        'bells', 'bellucci', 'belly', 'belo', 'belomoda', 'belong',
#        'belonging', 'belongings', 'belove', 'beloved', 'belowrelaxation',
#        'belsius', 'belt', 'belt1', 'belt100', 'belt2', 'beltadvent',
#        'beltblack', 'beltcolourblackbrownitalian', 'beltdenim',
#        'beltdrive', 'beltdriven', 'beltgift', 'belton', 'beltreversible',
#        'belts', 'beltscarf'], dtype=object)

# %%
for word in feature_names:
  idx=v.vocabulary_.get(word)
  print(f"{word} --> {idx}")
# Out:
# belarus --> 10000
# belazo --> 10001
# belegal --> 10002
# belem --> 10003
# belgian --> 10004
# belgium --> 10005
# belha --> 10006
# belief --> 10007
# beliefs --> 10008
# believable --> 10009
# believably --> 10010
# believe --> 10011
# believer --> 10012
# believers --> 10013
# belittling --> 10014
# belkin --> 10015
# bell --> 10016
# bella --> 10017
# bellaigue --> 10018
# belle --> 10019
# bellevue --> 10020
# bellingham --> 10021
# bellows --> 10022
# bells --> 10023
# bellucci --> 10024
# belly --> 10025
# belo --> 10026
# belomoda --> 10027
# belong --> 10028
# belonging --> 10029
# belongings --> 10030
# belove --> 10031
# beloved --> 10032
# belowrelaxation --> 10033
# belsius --> 10034
# belt --> 10035
# belt1 --> 10036
# belt100 --> 10037
# belt2 --> 10038
# beltadvent --> 10039
# beltblack --> 10040
# beltcolourblackbrownitalian --> 10041
# beltdenim --> 10042
# beltdrive --> 10043
# beltdriven --> 10044
# beltgift --> 10045
# belton --> 10046
# beltreversible --> 10047
# belts --> 10048
# beltscarf --> 10049

# %%
df.Text[0:2]
# Out:
# 0    Urban Ladder Eisner Low StudyOffice Computer C...
# 1    contrast live Wooden Decorative BoxPainted Box...
# Name: Text, dtype: object

# %%
v.fit_transform(df.Text[0:2]).toarray()
# Out:
# array([[0.        , 0.        , 0.12450853, 0.12450853, 0.        ,
#         0.12450853, 0.12450853, 0.        , 0.        , 0.        ,
#         0.12450853, 0.12450853, 0.12450853, 0.12450853, 0.        ,
#         0.        , 0.24901707, 0.12450853, 0.        , 0.        ,
#         0.12450853, 0.12450853, 0.        , 0.        , 0.        ,
#         0.12450853, 0.08858885, 0.12450853, 0.12450853, 0.12450853,
#         0.12450853, 0.24901707, 0.        , 0.12450853, 0.12450853,
#         0.        , 0.12450853, 0.12450853, 0.12450853, 0.12450853,
#         0.        , 0.12450853, 0.        , 0.        , 0.12450853,
#         0.        , 0.12450853, 0.        , 0.12450853, 0.12450853,
#         0.        , 0.12450853, 0.12450853, 0.12450853, 0.12450853,
#         0.        , 0.        , 0.12450853, 0.12450853, 0.12450853,
#         0.        , 0.12450853, 0.12450853, 0.        , 0.12450853,
#         0.12450853, 0.12450853, 0.        , 0.12450853, 0.        ,
#         0.12450853, 0.        , 0.12450853, 0.        , 0.        ,
#         0.24901707, 0.12450853, 0.24901707, 0.        , 0.12450853,
#         0.12450853, 0.        , 0.12450853, 0.12450853, 0.12450853,
#         0.        ],
#        [0.07844495, 0.07844495, 0.        , 0.        , 0.15688989,
#         0.        , 0.        , 0.15688989, 0.62755958, 0.07844495,
#         0.        , 0.        , 0.        , 0.        , 0.07844495,
#         0.07844495, 0.        , 0.        , 0.07844495, 0.07844495,
#         0.        , 0.        , 0.07844495, 0.23533484, 0.15688989,
#         0.        , 0.05581423, 0.        , 0.        , 0.        ,
#         0.        , 0.        , 0.07844495, 0.        , 0.        ,
#         0.15688989, 0.        , 0.        , 0.        , 0.        ,
#         0.07844495, 0.        , 0.23533484, 0.15688989, 0.        ,
#         0.23533484, 0.        , 0.07844495, 0.        , 0.        ,
#         0.15688989, 0.        , 0.        , 0.        , 0.        ,
#         0.07844495, 0.07844495, 0.        , 0.        , 0.        ,
#         0.07844495, 0.        , 0.        , 0.07844495, 0.        ,
#         0.        , 0.        , 0.07844495, 0.        , 0.07844495,
#         0.        , 0.07844495, 0.        , 0.07844495, 0.07844495,
#         0.        , 0.        , 0.        , 0.07844495, 0.        ,
#         0.        , 0.07844495, 0.        , 0.        , 0.        ,
#         0.39222473]])
